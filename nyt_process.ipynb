# %%
# climate+change
# gun+control
# medicare+for+all
# brexit
# north+korea
# fake+news
import pandas as pd
import urllib3
from bs4 import BeautifulSoup

# %%
#1 change file name here based on sub-topic
df = pd.read_csv("./nyt_out.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                       _id  \
# 0           0  5c8b5f9d40d36ff0709c6bc5
# 1           1  5c8b5f9d40d36ff0709c6bc8
# 2           2  5c9e4ef640d36ff0709d09a1
# 3           3  5c8b5f9c40d36ff0709c6bb3
# 4           4  5c8b5f9c40d36ff0709c6bbc
#
#                                             abstract blog  \
# 0  Readers respond to columns by Bret Stephens, D...   {}
# 1  The Green New Deal was introduced as a sweepin...   {}
# 2  Readers berate politicians for not taking acti...   {}
# 3  Readers discuss an ambitious 10-year plan to c...   {}
# 4  The controversial proposal to combat global wa...   {}
#
#                                               byline document_type  \
# 0  {'original': None, 'person': None, 'organizati...       article
# 1  {'original': 'By Robin Lindsay', 'person': [{'...    multimedia
# 2  {'original': None, 'person': None, 'organizati...       article
# 3  {'original': None, 'person': None, 'organizati...       article
# 4  {'original': None, 'person': None, 'organizati...       article
#
#                                             headline  \
# 0  {'main': 'Is the Green New Deal a Good Deal?',...
# 1  {'main': 'How Politicians Are Reacting to a Gr...
# 2  {'main': 'The Senate’s ‘Sham Vote’ on the Gree...
# 3  {'main': 'Appraising the Green New Deal', 'kic...
# 4  {'main': 'Promise and Peril of the Green New D...
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Green New Deal'...
# 1  [{'name': 'subject', 'value': 'Green New Deal'...
# 2  [{'name': 'subject', 'value': 'Green New Deal'...
# 3  [{'name': 'subject', 'value': 'Green New Deal'...
# 4  [{'name': 'persons', 'value': 'Ocasio-Cortez, ...
#
#                                       lead_paragraph  \
# 0                                     To the Editor:
# 1  The Green New Deal was introduced as a sweepin...
# 2                                     To the Editor:
# 3                                     To the Editor:
# 4  Listen and subscribe to our podcast from your ...
#
#                                           multimedia  ... print_page  \
# 0  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...  ...       26.0
# 1  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...  ...        NaN
# 2  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...  ...        NaN
# 3  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...  ...       10.0
# 4                                                 []  ...        NaN
#
#                    pub_date section_name  \
# 0  2019-02-20T20:11:20+0000      Opinion
# 1  2019-02-21T17:16:56+0000         U.S.
# 2  2019-03-29T16:59:32+0000      Opinion
# 3  2019-03-02T18:00:00+0000      Opinion
# 4  2019-03-07T11:00:06+0000     Podcasts
#
#                                              snippet              source  \
# 0  Readers respond to columns by Bret Stephens, D...  The New York Times
# 1  The Green New Deal was introduced as a sweepin...  The New York Times
# 2  Readers berate politicians for not taking acti...  The New York Times
# 3  Readers discuss an ambitious 10-year plan to c...  The New York Times
# 4  The controversial proposal to combat global wa...  The New York Times
#
#   subsection_name type_of_material  \
# 0         Letters           Letter
# 1        Politics            Video
# 2         Letters           Letter
# 3         Letters           Letter
# 4       The Daily             News
#
#                                                  uri  \
# 0  nyt://article/288ea404-120f-574a-a59a-09ce3d03...
# 1   nyt://video/6ac99dfb-05df-5adf-b98f-d1700d626c67
# 2  nyt://article/f511f71e-55d8-5099-a8f4-893e6373...
# 3  nyt://article/55e99a9f-7e75-510b-96e2-b9df6d6e...
# 4  nyt://article/c43bb101-e9f9-57f1-8027-56825265...
#
#                                              web_url word_count
# 0  https://www.nytimes.com/2019/02/20/opinion/let...        532
# 1  https://www.nytimes.com/video/us/politics/1000...          0
# 2  https://www.nytimes.com/2019/03/29/opinion/let...        296
# 3  https://www.nytimes.com/2019/03/02/opinion/let...       1190
# 4  https://www.nytimes.com/2019/03/07/podcasts/th...        296
#
# [5 rows x 21 columns]

# %%
df = df["web_url"]

# %%
http = urllib3.PoolManager()

text = ""
for url in df:
    
    response = http.request('GET', url)
    
    soup = BeautifulSoup(response.data, 'html.parser')
    
    matches = soup.select("main#site-content article#story section div.StoryBodyCompanionColumn > div > p")
    for item in matches:
        text += item.get_text()
# Out:
# c:\users\socket_var\appdata\local\continuum\anaconda3\envs\lab2_mr\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\socket_var\appdata\local\continuum\anaconda3\envs\lab2_mr\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\socket_var\appdata\local\continuum\anaconda3\envs\lab2_mr\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\socket_var\appdata\local\continuum\anaconda3\envs\lab2_mr\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\socket_var\appdata\local\continuum\anaconda3\envs\lab2_mr\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\socket_var\appdata\local\continuum\anaconda3\envs\lab2_mr\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\socket_var\appdata\local\continuum\anaconda3\envs\lab2_mr\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\socket_var\appdata\local\continuum\anaconda3\envs\lab2_mr\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\socket_var\appdata\local\continuum\anaconda3\envs\lab2_mr\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\socket_var\appdata\local\continuum\anaconda3\envs\lab2_mr\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\socket_var\appdata\local\continuum\anaconda3\envs\lab2_mr\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\socket_var\appdata\local\continuum\anaconda3\envs\lab2_mr\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\socket_var\appdata\local\continuum\anaconda3\envs\lab2_mr\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\socket_var\appdata\local\continuum\anaconda3\envs\lab2_mr\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\socket_var\appdata\local\continuum\anaconda3\envs\lab2_mr\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\socket_var\appdata\local\continuum\anaconda3\envs\lab2_mr\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\socket_var\appdata\local\continuum\anaconda3\envs\lab2_mr\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\socket_var\appdata\local\continuum\anaconda3\envs\lab2_mr\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\socket_var\appdata\local\continuum\anaconda3\envs\lab2_mr\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# c:\users\socket_var\appdata\local\continuum\anaconda3\envs\lab2_mr\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
#2 change file name here based on sub-topic
file = open("nyt.txt", "w") 
file.write(text)
file.close()
