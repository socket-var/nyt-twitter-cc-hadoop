# %%
import pandas as pd

# %%
#1 change file name
df = pd.read_csv("./input/raw/twitter_golf_day1.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  contributors coordinates                      created_at  \
# 0           0           NaN         NaN  Sat Apr 20 03:09:28 +0000 2019
# 1           1           NaN         NaN  Sat Apr 20 03:09:27 +0000 2019
# 2           2           NaN         NaN  Sat Apr 20 03:09:27 +0000 2019
# 3           3           NaN         NaN  Sat Apr 20 03:09:24 +0000 2019
# 4           4           NaN         NaN  Sat Apr 20 03:09:24 +0000 2019
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [{'text': 'OCUgolf', 'indices': [...
#
#                                    extended_entities  favorite_count  \
# 0                                                NaN               0
# 1                                                NaN               0
# 2  {'media': [{'id': 1116147527877660674, 'id_str...               0
# 3                                                NaN               0
# 4                                                NaN               0
#
#    favorited  geo                   id  ...  possibly_sensitive quoted_status  \
# 0      False  NaN  1119437903040479232  ...                 NaN           NaN
# 1      False  NaN  1119437897135001600  ...                 NaN           NaN
# 2      False  NaN  1119437896358850561  ...               False           NaN
# 3      False  NaN  1119437885923581955  ...                 NaN           NaN
# 4      False  NaN  1119437885604868096  ...               False           NaN
#
#    quoted_status_id  quoted_status_id_str  retweet_count  retweeted  \
# 0               NaN                   NaN              0      False
# 1               NaN                   NaN              0      False
# 2               NaN                   NaN              0      False
# 3               NaN                   NaN              0      False
# 4               NaN                   NaN              0      False
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://www.aainc.co.jp/" rel="nofollo...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://www.sidearmsports.com" rel="no...
#
#                                                 text truncated  \
# 0  @realDonaldTrump Still les than your golf outi...     False
# 1         Top golf is definitely not my thing 🤦🏼‍♀️😅     False
# 2  @atarutoiina1 ご参加ありがとうございます！\r\n抽選結果はムービーをご覧くだ...     False
# 3  @realDonaldTrump A.  It has cost taxpayers mor...      True
# 4  Stars stand in second place in SAC Championshi...     False
#
#                                                 user
# 0  {'id': 35229046, 'id_str': '35229046', 'name':...
# 1  {'id': 555301112, 'id_str': '555301112', 'name...
# 2  {'id': 1057921974020632576, 'id_str': '1057921...
# 3  {'id': 1100353448233574400, 'id_str': '1100353...
# 4  {'id': 53120013, 'id_str': '53120013', 'name':...
#
# [5 rows x 30 columns]

# %%
# remove duplicate tweets
df = df.drop_duplicates(subset="text", keep="first")

# %%
df = df["text"]

# %%
# for writing all text to file
pd.set_option('display.max_colwidth', -1)

# %%
text = df.to_string(index=False)

# %%
#2 change file name
file = open("input/mr/twitter_golf_day1.txt", "w", encoding='utf-8')
file.write(text)
file.close()
